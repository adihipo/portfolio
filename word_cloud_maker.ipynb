# %%
import numpy as np
from PIL import Image
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
def strip_whitespaces(text):
    return text.strip()

# %%
def do_wordcloud(text):
    dog_mask = np.array(Image.open('kepek/dog_mask.jpg'))
    wordcloud = WordCloud(background_color="rgba(255, 255, 255, 0)", mode="RGBA", mask=dog_mask, width=1600, height=800).generate(text)
    plt.figure()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()
    wordcloud.to_file('kepek/wc.png')

# %%
with open('kepek/wordcloud.txt') as f:
    lines = f.readlines()
    lines = map(strip_whitespaces, lines)
    lines = ' '.join(lines)
    lines = lines.replace('.', '')

# %%
print(lines)
# Out:
# bestest drink buddy jägermeister-meister Adam has a very positive attitude, he always smiles and see the glass half full He has a very massive knowledge in AI algoritms and skilled enough in Python to implement working machine learning models from zero He is a good team member and does his work 100% professional Adam is a true self-motivator, who is always eager to learn and genuinely enjoys complex challenges where he can utilize his extensive programming skills especially in the field of AI-based solutions His humble yet goal-oriented attitude makes him a really valuable member of any team Adam is a genuinely cheerful and positive person He is caring, nurturing, cooperative, appreciates others' boundaries Probably has very high EQ At work he's devoted to coding and AI development Motivated to find creative solutions in response to whatever problems are ahead of us

# %%
do_wordcloud(lines)
